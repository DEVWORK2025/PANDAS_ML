# %% [markdown]
# # DataFrames
#
# 1.DataFrames are the workhorse of pandas and are directly inspired by the R programming language.
#
# 2.We can think of a DataFrame as a bunch of Series objects put together to share the same index.

# %%
import pandas as pd
import numpy as np
#from numpy.random import randn

# %%
np.random.randn(5,4)
# Out:
# array([[ 0.64979184, -0.05778605,  0.407351  , -1.26636664],
#        [ 0.42216228,  0.33959147,  0.04733981,  0.3915658 ],
#        [ 0.25940203,  0.49225822, -0.16774663,  0.13186523],
#        [ 0.5368504 ,  1.35015562, -1.34605737, -0.43490879],
#        [-0.5223384 ,  0.23846544,  0.5916518 , -1.6811438 ]])

# %%
np.random.randn
# Out:
# <function RandomState.randn>

# %%
import pandas as pd
#from numpy.random import randn
import numpy as np
df =pd.DataFrame(np.random.randn(5,4))
df
# Out:
#           0         1         2         3
# 0 -0.151495 -0.018743 -0.423320  0.209943
# 1  0.575731  0.215779  0.157065 -0.961728
# 2 -2.530001 -0.029479  1.315190  0.224046
# 3 -0.711536  0.033538 -0.185493  0.913259
# 4 -1.003936  0.650550  1.363833 -0.075232

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns = ['A','B','C','D']

# %%
df
# Out:
#           A         B         C         D
# 0 -0.151495 -0.018743 -0.423320  0.209943
# 1  0.575731  0.215779  0.157065 -0.961728
# 2 -2.530001 -0.029479  1.315190  0.224046
# 3 -0.711536  0.033538 -0.185493  0.913259
# 4 -1.003936  0.650550  1.363833 -0.075232

# %%
df.index=['ramesh','suresh','mahesh','jitesh', 'sandesh']

# %%
df
# Out:
#                 A         B         C         D
# ramesh  -0.151495 -0.018743 -0.423320  0.209943
# suresh   0.575731  0.215779  0.157065 -0.961728
# mahesh  -2.530001 -0.029479  1.315190  0.224046
# jitesh  -0.711536  0.033538 -0.185493  0.913259
# sandesh -1.003936  0.650550  1.363833 -0.075232

# %%
type(df[1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-bd8909e3b7ec> in <module>
# ----> 1 type(df[1])
#
# ...

# %%
d1= {"a":[1,2,3,3,4],
    "b":[10,11,12,21,13],
    "c":[12,23,34,34,45],
    "d":["AA","BB","VV","CC","DD"]}

##df1=pd.DataFrame(d1)
df1=pd.DataFrame(d1, index=["P","Q","R","S",'T'])
df1
# Out:
#    a   b   c   d
# P  1  10  12  AA
# Q  2  11  23  BB
# R  3  12  34  VV
# S  3  21  34  CC
# T  4  13  45  DD

# %%
df.columns = ['P','C','M','B']

# %%
df1.columns
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.index
# Out:
# Index(['ramesh', 'suresh', 'mahesh', 'jitesh', 'sandesh'], dtype='object')

# %%
df
# Out:
#                 P         C         M         B
# ramesh  -0.816807  0.173738  1.267996  1.144825
# suresh   0.884122  1.249398  0.995159 -0.840734
# mahesh   1.568446  0.925711  1.949899  1.596078
# jitesh   0.165621  0.644158 -1.697730 -0.726570
# sandesh -1.157037 -0.149722  0.434665  0.668865

# %%
df.columns=["RANK","num1",'num2','name']

# %%
"A B C D".split()
# Out:
# ['A', 'B', 'C', 'D']

# %%
df.index="A B C D E".split()

# %%
df
# Out:
#              RANK      num1      num2      name
# ramesh  -0.816807  0.173738  1.267996  1.144825
# suresh   0.884122  1.249398  0.995159 -0.840734
# mahesh   1.568446  0.925711  1.949899  1.596078
# jitesh   0.165621  0.644158 -1.697730 -0.726570
# sandesh -1.157037 -0.149722  0.434665  0.668865

# %%
df.columns=['SER_NO','num1','num2','name']

# %%
df.columns
# Out:
# Index(['RANK', 'num1', 'num2', 'name'], dtype='object')

# %%
df.index
# Out:
# Index(['ramesh', 'suresh', 'mahesh', 'jitesh', 'sandesh'], dtype='object')

# %%
"A B C D E".split()
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
" A-X-D-V".split('-')
# Out:
# [' A', 'X', 'D', 'V']

# %%
from numpy.random import randn
df = pd.DataFrame(randn(5,4), columns=["W","X","Y","Z"],
                  index= "A B C D E".split())
df
# Out:
#           W         X         Y         Z
# A -0.597450  0.560151  0.914139 -0.971346
# B  0.967705 -1.098541 -0.675148 -1.052686
# C  0.684756  0.394821  0.478696  2.076421
# D -2.200623  0.446519  1.024712 -0.521015
# E -0.568054  0.967763  0.301893 -1.358282

# %%
df.columns
# Out:
# Index(['emp_no', 'id', 'pan_card', 'increment'], dtype='object')

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.columns = 'emp_no id pan_card increment '.split()

# %%
'W X Y Z'.split(" ")
# Out:
# ['W', 'X', 'Y', 'Z']

# %%
df
# Out:
#      emp_no        id  pan_card  increment
# A -0.597450  0.560151  0.914139  -0.971346
# B  0.967705 -1.098541 -0.675148  -1.052686
# C  0.684756  0.394821  0.478696   2.076421
# D -2.200623  0.446519  1.024712  -0.521015
# E -0.568054  0.967763  0.301893  -1.358282

# %%
info= ("NAME","MARKS","INDEX","MOBILE")

# %%
df['info']=info

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(5,4),index=['A','B','C','D' ,'E'],
                  columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A -0.709246 -0.414623  0.650393  1.263437
# B -0.320000 -1.553159 -0.546832  0.097043
# C -0.710211  1.057075 -0.227246  0.050060
# D  0.417901  0.455313 -0.055611 -0.301214
# E -0.762325  0.892807  1.025273 -0.141870

# %%
df.columns=['EMP_NO','MONTH','PERFORMANCE','RATING']

# %%
df.columns
# Out:
# Index(['EMP_NO', 'MONTH', 'PERFORMANCE', 'RATING'], dtype='object')

# %%
df.index="A B C D E".split()

# %%
new= pd.read_csv(r"C:\Users\Amrita\OneDrive\Desktop\abcd.csv" ,sep="\t" , 
                 error_bad_lines=False)
# Out:
# b'Skipping line 4: expected 4 fields, saw 5\n'

# %%
new= pd.read_csv(r"C:\Users\Amrita\OneDrive\Desktop\abcd.csv")

# %%
'E:\Python\Machine Learning\datasets'
# Out:
# 'E:\\Python\\Machine Learning\\datasets'

# %%
new
# Out:
#            col1  col2  col3  col4
# 0         anish    90    90    80
# 1  dfghjklsdfgh    89    80    67

# %%
new['A']
# Out:
# 0    amdkg
# 1     sdkl
# 2    asldk
# Name: A, dtype: object

# %%
import pandas as pd
adv=pd.read_csv(r"D:\ML_code\datasets\datasets\Advertising.csv")

# %%
adv
# Out:
#       Month     TV  radio  newspaper  sales
# 0    Jan-00  230.1   37.8       69.2   22.1
# 1    Feb-00   44.5   39.3       45.1   10.4
# 2    Mar-00   17.2   45.9       69.3    9.3
# 3    Apr-00  151.5   41.3       58.5   18.5
# 4    May-00  180.8   10.8       58.4   12.9
# ..      ...    ...    ...        ...    ...
# 195  16-Apr   38.2    3.7       13.8    7.6
# 196  16-May   94.2    4.9        8.1    9.7
# 197  16-Jun  177.0    9.3        6.4   12.8
# 198  16-Jul  283.6   42.0       66.2   25.5
# 199  16-Aug  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
adv.shape
# Out:
# (200, 5)

# %%
adv.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
adv.set_index('Month', inplace= True)

# %%
adv.index
# Out:
# Index(['Jan-00', 'Feb-00', 'Mar-00', 'Apr-00', 'May-00', 'Jun-00', 'Jul-00',
#        'Aug-00', 'Sep-00', 'Oct-00',
#        ...
#        '15-Nov', '15-Dec', '16-Jan', '16-Feb', '16-Mar', '16-Apr', '16-May',
#        '16-Jun', '16-Jul', '16-Aug'],
#       dtype='object', name='Month', length=200)

# %%
adv.head()
# Out:
#            TV  radio  newspaper  sales
# Month
# Jan-00  230.1   37.8       69.2   22.1
# Feb-00   44.5   39.3       45.1   10.4
# Mar-00   17.2   45.9       69.3    9.3
# Apr-00  151.5   41.3       58.5   18.5
# May-00  180.8   10.8       58.4   12.9

# %%
adv.tail(10)
# Out:
#       Month     TV  radio  newspaper  sales
# 190  15-Nov   39.5   41.1        5.8   10.8
# 191  15-Dec   75.5   10.8        6.0    9.9
# 192  16-Jan   17.2    4.1       31.6    5.9
# 193  16-Feb  166.8   42.0        3.6   19.6
# 194  16-Mar  149.7   35.6        6.0   17.3
# 195  16-Apr   38.2    3.7       13.8    7.6
# 196  16-May   94.2    4.9        8.1    9.7
# 197  16-Jun  177.0    9.3        6.4   12.8
# 198  16-Jul  283.6   42.0       66.2   25.5
# 199  16-Aug  232.1    8.6        8.7   13.4

# %%
adv.index = np.arange(1,201)

# %%
adv
# Out:
#       Month     TV  radio  newspaper  sales
# 1    Jan-00  230.1   37.8       69.2   22.1
# 2    Feb-00   44.5   39.3       45.1   10.4
# 3    Mar-00   17.2   45.9       69.3    9.3
# 4    Apr-00  151.5   41.3       58.5   18.5
# 5    May-00  180.8   10.8       58.4   12.9
# ..      ...    ...    ...        ...    ...
# 196  16-Apr   38.2    3.7       13.8    7.6
# 197  16-May   94.2    4.9        8.1    9.7
# 198  16-Jun  177.0    9.3        6.4   12.8
# 199  16-Jul  283.6   42.0       66.2   25.5
# 200  16-Aug  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
pd.options.display.max_info_columns =200

# %%
adv
# Out:
#            TV  radio  newspaper  sales
# Month
# Jan-00  230.1   37.8       69.2   22.1
# Feb-00   44.5   39.3       45.1   10.4
# Mar-00   17.2   45.9       69.3    9.3
# Apr-00  151.5   41.3       58.5   18.5
# May-00  180.8   10.8       58.4   12.9
# ...       ...    ...        ...    ...
# 16-Apr   38.2    3.7       13.8    7.6
# 16-May   94.2    4.9        8.1    9.7
# 16-Jun  177.0    9.3        6.4   12.8
# 16-Jul  283.6   42.0       66.2   25.5
# 16-Aug  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
pd.options.display.min_rows = 30

# %%
pd.options.display.max_columns=10

# %%
adv.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
adv.head(9)
# Out:
#     Month     TV  radio  newspaper  sales
# 1  Jan-00  230.1   37.8       69.2   22.1
# 2  Feb-00   44.5   39.3       45.1   10.4
# 3  Mar-00   17.2   45.9       69.3    9.3
# 4  Apr-00  151.5   41.3       58.5   18.5
# 5  May-00  180.8   10.8       58.4   12.9
# 6  Jun-00    8.7   48.9       75.0    7.2
# 7  Jul-00   57.5   32.8       23.5   11.8
# 8  Aug-00  120.2   19.6       11.6   13.2
# 9  Sep-00    8.6    2.1        1.0    4.8

# %%
adv.tail(7)
# Out:
#       Month     TV  radio  newspaper  sales
# 194  16-Feb  166.8   42.0        3.6   19.6
# 195  16-Mar  149.7   35.6        6.0   17.3
# 196  16-Apr   38.2    3.7       13.8    7.6
# 197  16-May   94.2    4.9        8.1    9.7
# 198  16-Jun  177.0    9.3        6.4   12.8
# 199  16-Jul  283.6   42.0       66.2   25.5
# 200  16-Aug  232.1    8.6        8.7   13.4

# %%
s = adv[['radio', 'TV']]

# %%
adv
# Out:
#            TV  radio  newspaper  sales
# Month
# Jan-00  230.1   37.8       69.2   22.1
# Feb-00   44.5   39.3       45.1   10.4
# Mar-00   17.2   45.9       69.3    9.3
# Apr-00  151.5   41.3       58.5   18.5
# May-00  180.8   10.8       58.4   12.9
# Jun-00    8.7   48.9       75.0    7.2
# Jul-00   57.5   32.8       23.5   11.8
# Aug-00  120.2   19.6       11.6   13.2
# Sep-00    8.6    2.1        1.0    4.8
# Oct-00  199.8    2.6       21.2   10.6
# Nov-00   66.1    5.8       24.2    8.6
# Dec-00  214.7   24.0        4.0   17.4
# 01-Jan   23.8   35.1       65.9    9.2
# 01-Feb   97.5    7.6        7.2    9.7
# 01-Mar  204.1   32.9       46.0   19.0
# ...       ...    ...        ...    ...
# 15-Jun  205.0   45.1       19.6   22.6
# 15-Jul  139.5    2.1       26.6   10.3
# 15-Aug  191.1   28.7       18.2   17.3
# 15-Sep  286.0   13.9        3.7   15.9
# 15-Oct   18.7   12.1       23.4    6.7
# 15-Nov   39.5   41.1        5.8   10.8
# 15-Dec   75.5   10.8        6.0    9.9
# ...

# %%
adv.iloc[30:40, 2:4]
# Out:
#         newspaper  sales
# Month
# 02-Jul       43.2   21.4
# 02-Aug       38.6   11.9
# 02-Sep       30.0    9.6
# 02-Oct        0.3   17.4
# 02-Nov        7.4    9.5
# 02-Dec        8.5   12.8
# 03-Jan        5.0   25.4
# 03-Feb       45.7   14.7
# 03-Mar       35.1   10.1
# 03-Apr       32.0   21.5

# %%
adv.loc['02-Mar':'03-Jun','TV']
# Out:
# Month
# 02-Mar    142.9
# 02-Apr    240.1
# 02-May    248.8
# 02-Jun     70.6
# 02-Jul    292.9
# 02-Aug    112.9
# 02-Sep     97.2
# 02-Oct    265.6
# 02-Nov     95.7
# 02-Dec    290.7
# 03-Jan    266.9
# 03-Feb     74.7
# 03-Mar     43.1
# 03-Apr    228.0
# 03-May    202.5
# 03-Jun    177.0
# Name: TV, dtype: float64

# %%
adv.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
df
# Out:
#      EMP_NO     MONTH  PERFORMANCE    RATING
# A -0.709246 -0.414623     0.650393  1.263437
# B -0.320000 -1.553159    -0.546832  0.097043
# C -0.710211  1.057075    -0.227246  0.050060
# D  0.417901  0.455313    -0.055611 -0.301214
# E -0.762325  0.892807     1.025273 -0.141870

# %%
df.reset_index(inplace= True)

# %%
df
# Out:
#    level_0 index    EMP_NO     MONTH  PERFORMANCE    RATING
# 0        0     A -0.709246 -0.414623     0.650393  1.263437
# 1        1     B -0.320000 -1.553159    -0.546832  0.097043
# 2        2     C -0.710211  1.057075    -0.227246  0.050060
# 3        3     D  0.417901  0.455313    -0.055611 -0.301214
# 4        4     E -0.762325  0.892807     1.025273 -0.141870

# %%
df.set_index('index')
# Out:
#          level_0      RANK      num1      num2      name
# index
# ramesh         0 -0.816807  0.173738  1.267996  1.144825
# suresh         1  0.884122  1.249398  0.995159 -0.840734
# mahesh         2  1.568446  0.925711  1.949899  1.596078
# jitesh         3  0.165621  0.644158 -1.697730 -0.726570
# sandesh        4 -1.157037 -0.149722  0.434665  0.668865

# %%
df.reset_index(inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-c28918558377> in <module>
# ----> 1 df.reset_index(inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5014                 # to ndarray and maybe infer different dtype
#    5015                 level_values = maybe_casted_values(lev, lab)
# -> 5016                 new_obj.insert(0, name, level_values)
#    5017
#    5018         new_obj.index = new_index
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
# ...

# %%
df123 = df.set_index('index')

# %%
df123['EMP_NO']
# Out:
# index
# A   -0.709246
# B   -0.320000
# C   -0.710211
# D    0.417901
# E   -0.762325
# Name: EMP_NO, dtype: float64

# %%
type(df123['EMP_NO'])
# Out:
# pandas.core.series.Series

# %%
df123
# Out:
#        level_0    EMP_NO     MONTH  PERFORMANCE    RATING
# index
# A            0 -0.709246 -0.414623     0.650393  1.263437
# B            1 -0.320000 -1.553159    -0.546832  0.097043
# C            2 -0.710211  1.057075    -0.227246  0.050060
# D            3  0.417901  0.455313    -0.055611 -0.301214
# E            4 -0.762325  0.892807     1.025273 -0.141870

# %%
df123.loc[ ['B','D'], ['EMP_NO','RATING']]
# Out:
#          EMP_NO    RATING
# index
# B     -0.320000  0.097043
# D      0.417901 -0.301214

# %%
df.loc[ ['suresh','mahesh','jitesh'], ['B','D']]
# Out:
#                B         D
# suresh  2.059939  1.515949
# mahesh -0.060613  0.297715
# jitesh -0.646537 -0.569611

# %%
df.iloc[1:4,[1,3]]
# Out:
#                B         D
# suresh  2.059939  1.515949
# mahesh -0.060613  0.297715
# jitesh -0.646537 -0.569611

# %%
df.reset_index()
# Out:
#      index         A         B         C         D
# 0   ramesh -2.599887 -0.095044  0.269633 -0.035895
# 1   suresh -1.707684  2.059939  0.077665  1.515949
# 2   mahesh -1.202461 -0.060613  0.181755  0.297715
# 3   jitesh  0.351479 -0.646537 -0.843714 -0.569611
# 4  sandesh  0.469401 -2.746411  0.681106  1.963722

# %% [markdown]
# ## Selection and Indexing
#
# methods to grab data from a DataFrame

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
adv[['TV','radio','newspaper']]
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# 5      8.7   48.9       75.0
# 6     57.5   32.8       23.5
# 7    120.2   19.6       11.6
# 8      8.6    2.1        1.0
# 9    199.8    2.6       21.2
# 10    66.1    5.8       24.2
# 11   214.7   24.0        4.0
# 12    23.8   35.1       65.9
# 13    97.5    7.6        7.2
# 14   204.1   32.9       46.0
# 15   195.4   47.7       52.9
# 16    67.8   36.6      114.0
# 17   281.4   39.6       55.8
# 18    69.2   20.5       18.3
# 19   147.3   23.9       19.1
# 20   218.4   27.7       53.4
# 21   237.4    5.1       23.5
# 22    13.2   15.9       49.6
# 23   228.3   16.9       26.2
# 24    62.3   12.6       18.3
# 25   262.9    3.5       19.5
# 26   142.9   29.3       12.6
# 27   240.1   16.7       22.9
# 28   248.8   27.1       22.9
# 29    70.6   16.0       40.8
# ..     ...    ...        ...
# ...

# %%
type(df["EMP_NO"])
# Out:
# pandas.core.series.Series

# %%
type(df[["EMP_NO","MONTH",'RATING']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[["EMP_NO","MONTH",'RATING']]
# Out:
#      EMP_NO     MONTH    RATING
# A -0.968136 -0.280405 -0.163386
# B -1.762345 -0.586636 -0.337883
# C -1.342856  1.093895  0.590490
# D  0.095086 -1.543299 -0.126009
# E  0.520460  0.506974 -1.156898

# %%
print(type(df["EMP_NO"]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df[["EMP_NO","RATING","MONTH"]]
# Out:
#      EMP_NO    RATING     MONTH
# A  1.359320  0.277480  0.927509
# B -2.035379 -1.013384  1.507987
# C -0.366854  0.182016 -2.056913
# D -0.352859 -0.537689 -0.356616
# E -1.248173 -0.248282  0.561731

# %%
print(df[['EMP_NO',"RATING"]])
type(df[['EMP_NO',"RATING"]])
# Out:
#      EMP_NO    RATING
# A -1.355366  0.376690
# B  1.389777  1.074569
# C -0.158755  0.018087
# D  0.750884  0.441881
# E -1.527149 -0.717808
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      EMP_NO     MONTH  PERFORMANE    RATING
# A  1.524303 -0.040914   -0.215922 -0.532263
# B  0.762621  0.176411   -0.371835  0.010375
# C -1.151182 -0.196754    1.437688  0.555817
# D  0.891128  0.767386    0.152350  0.012037
# E  0.843282 -0.781700    1.759080  0.510463

# %%
df
# Out:
#           W         X         Y         Z
# A -0.767763  0.660504  0.668966 -0.463456
# B  1.255684 -0.064614  0.256751 -1.808088
# C -1.002467  0.923070  0.722617  1.314495
# D -2.068051  0.985353 -0.034651 -0.089781
# E -0.544011  0.099837 -0.636896  0.293113

# %%
df
# Out:
#      EMP_NO     MONTH  PERFORMANE    RATING  Salary
# A -0.334026 -0.526200    1.033805 -0.066458   25000
# B  1.008031  0.445140   -0.723682  2.450490  200000
# C -0.982736  0.001794   -0.114752 -0.034991   35000
# D -0.937423  0.388053    1.578309 -0.971299  100000
# E -0.735566  0.317681   -0.558643  0.334646   24000

# %% [markdown]
# DataFrame Columns are just Series

# %%
df
# Out:
#    level_0    index      RANK      num1      num2      name
# 0        0   ramesh -0.816807  0.173738  1.267996  1.144825
# 1        1   suresh  0.884122  1.249398  0.995159 -0.840734
# 2        2   mahesh  1.568446  0.925711  1.949899  1.596078
# 3        3   jitesh  0.165621  0.644158 -1.697730 -0.726570
# 4        4  sandesh -1.157037 -0.149722  0.434665  0.668865

# %%
df.shape
# Out:
# (5, 6)

# %%
adv['new'] = adv['TV']+adv['radio']

# %%
adv.head(2)
# Out:
#     Month     TV  radio  newspaper  sales    new
# 0  Jan-00  230.1   37.8       69.2   22.1  267.9
# 1  Feb-00   44.5   39.3       45.1   10.4   83.8

# %%
sal=[25000,200000,35000,100000,24000]

# %%
df["Salary"]=sal

# %%
df
# Out:
#    level_0 index    EMP_NO     MONTH  PERFORMANCE    RATING  Salary
# 0        0     A -0.709246 -0.414623     0.650393  1.263437   25000
# 1        1     B -0.320000 -1.553159    -0.546832  0.097043  200000
# 2        2     C -0.710211  1.057075    -0.227246  0.050060   35000
# 3        3     D  0.417901  0.455313    -0.055611 -0.301214  100000
# 4        4     E -0.762325  0.892807     1.025273 -0.141870   24000

# %% [markdown]
# **Creating a new column:**

# %%
df['increment'] = df['Salary'] * df['RATING']

# %%
df
# Out:
#    level_0 index    EMP_NO     MONTH  PERFORMANCE    RATING  Salary  \
# 0        0     A -0.709246 -0.414623     0.650393  1.263437   25000
# 1        1     B -0.320000 -1.553159    -0.546832  0.097043  200000
# 2        2     C -0.710211  1.057075    -0.227246  0.050060   35000
# 3        3     D  0.417901  0.455313    -0.055611 -0.301214  100000
# 4        4     E -0.762325  0.892807     1.025273 -0.141870   24000
#
#       increment
# 0  31585.915621
# 1  19408.629175
# 2   1752.112317
# 3 -30121.403647
# 4  -3404.876545

# %%
df['new1'] = [1,np.nan,3,4,5]

# %%
df.set_index('index', inplace = True)

# %%
df.loc["jitesh",'increment']=np.nan

# %%
df
# Out:
#          level_0      RANK      num1      num2      name  Salary  \
# index
# ramesh         0 -0.816807  0.173738  1.267996  1.144825   25000
# suresh         1  0.884122  1.249398  0.995159 -0.840734  200000
# mahesh         2  1.568446  0.925711  1.949899  1.596078   35000
# jitesh         3  0.165621  0.644158 -1.697730 -0.726570  100000
# sandesh        4 -1.157037 -0.149722  0.434665  0.668865   24000
#
#              increment  new1
# index
# ramesh    31699.901511   1.0
# suresh   199031.895120   NaN
# mahesh    68246.472729   3.0
# jitesh             NaN   4.0
# sandesh   10431.964356   5.0

# %%
df.isna().sum()
# Out:
# level_0        0
# index          0
# EMP_NO         0
# MONTH          0
# PERFORMANCE    0
# RATING         0
# Salary         0
# increment      0
# dtype: int64

# %%
df.dropna()
# Out:
#          level_0      RANK      num1      num2      name  Salary  \
# index
# ramesh         0 -0.816807  0.173738  1.267996  1.144825   25000
# mahesh         2  1.568446  0.925711  1.949899  1.596078   35000
# sandesh        4 -1.157037 -0.149722  0.434665  0.668865   24000
#
#             increment  new1
# index
# ramesh   31699.901511   1.0
# mahesh   68246.472729   3.0
# sandesh  10431.964356   5.0

# %%
randn(5,2)
# Out:
# array([[-0.3539129 ,  0.88087069],
#        [-0.80371997, -0.22419991],
#        [-0.54663794,  0.88452282],
#        [ 0.65945596,  0.78298427],
#        [-0.33056179,  1.06088293]])

# %%
df['new3'] = np.random.randn(5,2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'new3'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
# ...

# %%
df
# Out:
#      EMP_NO     MONTH  PERFORMANCE    RATING  Salary     increment      new1
# A -0.968136 -0.280405    -1.558455 -0.163386   25000  -4084.649758  0.112391
# B -1.762345 -0.586636          NaN -0.337883  200000 -67576.527129 -1.022462
# C -1.342856  1.093895          NaN  0.590490   35000  20667.155630  0.132308
# D  0.095086 -1.543299    -0.802618 -0.126009  100000 -12600.935019 -0.775561
# E  0.520460  0.506974     0.539481 -1.156898   24000 -27765.555049  0.600884

# %% [markdown]
# ** Removing Columns**

# %%
df
# Out:
#              RANK      num1      num2      name  Salary      increment  new1
# index
# ramesh  -0.816807  0.173738  1.267996  1.144825   25000   31699.901511   1.0
# suresh   0.884122  1.249398  0.995159 -0.840734  200000  199031.895120   NaN
# mahesh   1.568446  0.925711  1.949899  1.596078   35000   68246.472729   3.0
# jitesh   0.165621  0.644158 -1.697730 -0.726570  100000            NaN   4.0
# sandesh -1.157037 -0.149722  0.434665  0.668865   24000   10431.964356   5.0

# %%
df
# Out:
#    level_0 index    EMP_NO     MONTH  PERFORMANCE    RATING  Salary  \
# 0        0     A -0.709246 -0.414623     0.650393  1.263437   25000
# 1        1     B -0.320000 -1.553159    -0.546832  0.097043  200000
# 2        2     C -0.710211  1.057075    -0.227246  0.050060   35000
# 3        3     D  0.417901  0.455313    -0.055611 -0.301214  100000
# 4        4     E -0.762325  0.892807     1.025273 -0.141870   24000
#
#       increment
# 0  31585.915621
# 1  19408.629175
# 2   1752.112317
# 3 -30121.403647
# 4  -3404.876545

# %%
df.drop('level_0',axis=1)
# Out:
#   index    EMP_NO     MONTH  PERFORMANCE    RATING  Salary     increment
# 0     A -0.709246 -0.414623     0.650393  1.263437   25000  31585.915621
# 1     B -0.320000 -1.553159    -0.546832  0.097043  200000  19408.629175
# 2     C -0.710211  1.057075    -0.227246  0.050060   35000   1752.112317
# 3     D  0.417901  0.455313    -0.055611 -0.301214  100000 -30121.403647
# 4     E -0.762325  0.892807     1.025273 -0.141870   24000  -3404.876545

# %%
df
# Out:
#              RANK      num1      num2      name  Salary      increment  new1
# index
# ramesh  -0.816807  0.173738  1.267996  1.144825   25000   31699.901511   1.0
# suresh   0.884122  1.249398  0.995159 -0.840734  200000  199031.895120   NaN
# mahesh   1.568446  0.925711  1.949899  1.596078   35000   68246.472729   3.0
# jitesh   0.165621  0.644158 -1.697730 -0.726570  100000            NaN   4.0
# sandesh -1.157037 -0.149722  0.434665  0.668865   24000   10431.964356   5.0

# %%
# Not inplace unless specified!
df
# Out:
#      EMP_NO     MONTH  PERFORMANCE    RATING  Salary     increment      new1
# A -0.968136 -0.280405    -1.558455 -0.163386   25000  -4084.649758  0.112391
# D  0.095086 -1.543299    -0.802618 -0.126009  100000 -12600.935019 -0.775561

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#      EMP_NO     MONTH  PERFORMANCE    RATING  Salary     increment      new1
# A -0.968136 -0.280405    -1.558455 -0.163386   25000  -4084.649758  0.112391
# D  0.095086 -1.543299    -0.802618 -0.126009  100000 -12600.935019 -0.775561

# %%
dfd = df.drop("Salary",axis=1)

# %%
dfd
# Out:
#      EMP_NO     MONTH  PERFORMANCE    RATING     increment      new1
# A -0.968136 -0.280405    -1.558455 -0.163386  -4084.649758  0.112391
# D  0.095086 -1.543299    -0.802618 -0.126009 -12600.935019 -0.775561

# %%
df.drop('new',axis=1,inplace=True)

# %%
df
# Out:
#              RANK      num1      num2      name  Salary      increment  new1
# index
# ramesh  -0.816807  0.173738  1.267996  1.144825   25000   31699.901511   1.0
# suresh   0.884122  1.249398  0.995159 -0.840734  200000  199031.895120   NaN
# mahesh   1.568446  0.925711  1.949899  1.596078   35000   68246.472729   3.0
# jitesh   0.165621  0.644158 -1.697730 -0.726570  100000            NaN   4.0
# sandesh -1.157037 -0.149722  0.434665  0.668865   24000   10431.964356   5.0

# %% [markdown]
# Can also drop rows this way:

# %%
df.drop('sandesh',axis=0)
# Out:
#             RANK      num1      num2      name  Salary      increment  new1
# index
# ramesh -0.816807  0.173738  1.267996  1.144825   25000   31699.901511   1.0
# suresh  0.884122  1.249398  0.995159 -0.840734  200000  199031.895120   NaN
# mahesh  1.568446  0.925711  1.949899  1.596078   35000   68246.472729   3.0
# jitesh  0.165621  0.644158 -1.697730 -0.726570  100000            NaN   4.0

# %% [markdown]
# ** Selecting Rows**

# %%
df.drop("level_0", inplace = True, axis = 1)

# %%
df
# Out:
#      EMP_NO     MONTH  PERFORMANCE    RATING  Salary     increment      new1
# A -0.968136 -0.280405    -1.558455 -0.163386   25000  -4084.649758  0.112391
# D  0.095086 -1.543299    -0.802618 -0.126009  100000 -12600.935019 -0.775561

# %%
df['u_id'] = ["A100","A101"]

# %%
df['u_id'][0]="A101"
# Out:
# <ipython-input-114-d61f5151fc31>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['u_id'][0]="A101"

# %%
df
# Out:
#         EMP_NO     MONTH  PERFORMANCE    RATING  Salary     increment  \
# u_id
# A100 -0.968136 -0.280405    -1.558455 -0.163386   25000  -4084.649758
# A101  0.095086 -1.543299    -0.802618 -0.126009  100000 -12600.935019
#
#           new1
# u_id
# A100  0.112391
# A101 -0.775561

# %%
df.set_index("u_id", inplace =True)

# %%
df['EMP_NO']['A100']
# Out:
# -0.9681364683311493

# %%
df.reset_index(inplace = True)

# %%
df.columns
# Out:
# Index(['level_0', 'index', 'EMP_NO', 'MONTH', 'PERFORMANCE', 'RATING',
#        'Salary', 'increment'],
#       dtype='object')

# %%
df.set_index("index", inplace  = True)

# %%
df['Salary']['A100']=50000
# Out:
# <ipython-input-77-31a457f34a88>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salary']['A100']=50000

# %%
df["Salary"][0]=50000
# Out:
# <ipython-input-123-42ba9f794c1d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Salary"][0]=50000

# %%
df
# Out:
#         EMP_NO     MONTH  PERFORMANCE    RATING  Salary     increment  \
# u_id
# A100 -0.968136 -0.280405    -1.558455 -0.163386   50000  -4084.649758
# A101  0.095086 -1.543299    -0.802618 -0.126009  100000 -12600.935019
#
#           new1
# u_id
# A100  0.112391
# A101 -0.775561

# %%
df.iloc[1, 2:6]
# Out:
# PERFORMANCE        -0.802618
# RATING             -0.126009
# Salary         100000.000000
# increment      -12600.935019
# Name: A101, dtype: float64

# %%
df.loc[["A100","A101"],["MONTH","Salary"]]
# Out:
#          MONTH  Salary
# u_id
# A100 -0.280405   50000
# A101 -1.543299  100000

# %%
df.columns
# Out:
# Index(['EMP_NO', 'MONTH', 'PERFORMANE', 'RATING', 'Salary', 'increment',
#        'new1'],
#       dtype='object')

# %%
df[["MONTH","EMP_NO","Salary"]]
# Out:
#       MONTH    EMP_NO  Salary
# A  0.687739 -1.355366   25000
# C -0.356732 -0.158755   35000
# D  0.656187  0.750884  100000
# E -0.961238 -1.527149   50000

# %%
df.loc[["B","D"],["EMP_NO", "RATING","Salary"]]
# Out:
#      EMP_NO    RATING  Salary
# B  1.008031  2.450490  200000
# D -0.937423 -0.971299  100000

# %% [markdown]
# Or select based off of position instead of label

# %%
df.loc[["E"],["Salary"]]=50000

# %%
df
# Out:
#         EMP_NO     MONTH  PERFORMANCE    RATING  Salary     increment
# u_id
# A101  1.359320  0.927509     0.179685  0.277480   50000   6937.000921
# A101 -0.366854 -2.056913     0.753300  0.182016   35000   6370.553081
# A102 -0.352859 -0.356616    -1.113207 -0.537689  100000 -53768.937937
# A103 -1.248173  0.561731     1.272418 -0.248282   24000  -5958.770336

# %%
df.iloc[:2 ,1:3]
# Out:
#          MONTH  PERFORMANCE
# u_id
# A101  0.927509     0.179685
# A101 -2.056913     0.753300

# %%
#df.iloc['W','A']
df.iloc[2:4,1:]
# Out:
#       MONTH  PERFORMANE    RATING  Salary     increment  new1
# C  0.001794   -0.114752 -0.034991   35000  -1224.682348   3.0
# D  0.388053    1.578309 -0.971299  100000 -97129.906896   4.0

# %% [markdown]
# ** Selecting subset of rows and columns **

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.loc['B','Y']
# Out:
# 0.2567508599091483

# %%
df.loc[['A','C'],['X','Z']]
# Out:
#           X         Z
# A  0.660504 -0.463456
# C  0.923070  1.314495

# %% [markdown]
# ### Conditional Selection
#
# An important feature of pandas is conditional selection using bracket notation, very similar to numpy:

# %%
df.reset_index(inplace =True)

# %%
df[df[['RANK','num1','num2','name','Salary','increment','new1']]<0]
# Out:
#   index      RANK      num1     num2      name  Salary  increment  new1
# 0   NaN -0.816807       NaN      NaN       NaN     NaN        NaN   NaN
# 1   NaN       NaN       NaN      NaN -0.840734     NaN        NaN   NaN
# 2   NaN       NaN       NaN      NaN       NaN     NaN        NaN   NaN
# 3   NaN       NaN       NaN -1.69773 -0.726570     NaN        NaN   NaN
# 4   NaN -1.157037 -0.149722      NaN       NaN     NaN        NaN   NaN

# %%
df
# Out:
#    level_0 index    EMP_NO     MONTH  PERFORMANCE    RATING  Salary  \
# 0        0     A -0.709246 -0.414623     0.650393  1.263437   25000
# 1        1     B -0.320000 -1.553159    -0.546832  0.097043  200000
# 2        2     C -0.710211  1.057075    -0.227246  0.050060   35000
# 3        3     D  0.417901  0.455313    -0.055611 -0.301214  100000
# 4        4     E -0.762325  0.892807     1.025273 -0.141870   24000
#
#       increment
# 0  31585.915621
# 1  19408.629175
# 2   1752.112317
# 3 -30121.403647
# 4  -3404.876545

# %%
df[df['Salary']> 25000][['MONTH','RATING']]
# Out:
#       MONTH    RATING
# 1 -1.553159  0.097043
# 2  1.057075  0.050060
# 3  0.455313 -0.301214

# %%
df[df['RANK']<0]
# Out:
#      index      RANK      num1      num2      name  Salary     increment  new1
# 0   ramesh -0.816807  0.173738  1.267996  1.144825   25000  31699.901511   1.0
# 4  sandesh -1.157037 -0.149722  0.434665  0.668865   24000  10431.964356   5.0

# %%
df['name']=['amas','tama']
df
# Out:
#         EMP_NO     MONTH  PERFORMANCE    RATING  Salary     increment  \
# u_id
# A100 -0.968136 -0.280405    -1.558455 -0.163386   50000  -4084.649758
# A101  0.095086 -1.543299    -0.802618 -0.126009  100000 -12600.935019
#
#           new1  name
# u_id
# A100  0.112391  amas
# A101 -0.775561  tama

# %%
df.drop("name",axis =1,inplace = True)

# %%
df
# Out:
#         EMP_NO     MONTH  PERFORMANCE    RATING  Salary     increment  \
# u_id
# A100 -0.968136 -0.280405    -1.558455 -0.163386   50000  -4084.649758
# A101  0.095086 -1.543299    -0.802618 -0.126009  100000 -12600.935019
#
#           new1
# u_id
# A100  0.112391
# A101 -0.775561

# %%
df['MONTH']>0
# Out:
# u_id
# A100    False
# A101    False
# Name: MONTH, dtype: bool

# %%
df[df["new1"]>0]
# Out:
#         EMP_NO     MONTH  PERFORMANCE    RATING  Salary    increment      new1
# u_id
# A100 -0.968136 -0.280405    -1.558455 -0.163386   50000 -4084.649758  0.112391

# %%
df[df["PERFORMANCE"]>0]
# Out:
#         EMP_NO     MONTH  PERFORMANCE    RATING  Salary    increment
# u_id
# A101  1.359320  0.927509     0.179685  0.277480   50000  6937.000921
# A101 -0.366854 -2.056913     0.753300  0.182016   35000  6370.553081
# A103 -1.248173  0.561731     1.272418 -0.248282   24000 -5958.770336

# %%
df['PERFORMANCE']==0
# Out:
# u_id
# A100    False
# A101    False
# Name: PERFORMANCE, dtype: bool

# %%
df
# Out:
#      index      RANK      num1      num2      name  Salary      increment  \
# 0   ramesh -0.816807  0.173738  1.267996  1.144825   25000   31699.901511
# 1   suresh  0.884122  1.249398  0.995159 -0.840734  200000  199031.895120
# 2   mahesh  1.568446  0.925711  1.949899  1.596078   35000   68246.472729
# 3   jitesh  0.165621  0.644158 -1.697730 -0.726570  100000            NaN
# 4  sandesh -1.157037 -0.149722  0.434665  0.668865   24000   10431.964356
#
#    new1
# 0   1.0
# 1   NaN
# 2   3.0
# 3   4.0
# 4   5.0

# %%
df[df['num2']>0] [['num1','num2','Salary']]
# Out:
#        num1      num2  Salary
# 0  0.173738  1.267996   25000
# 1  1.249398  0.995159  200000
# 2  0.925711  1.949899   35000
# 4 -0.149722  0.434665   24000

# %%
df[df['W']>0][['Y','X',"W"]]
# Out:
#           Y         X         W
# B  0.256751 -0.064614  1.255684

# %%
df.dropna

# %% [markdown]
# For two conditions you can use | and & with parenthesis:

# %%
df[(df['W']>0)]

# %% [markdown]
# ## More Index Details
#
# More features of indexing, including resetting the index or setting it something else.

# %%
df

# %%
df
# Out:
#    level_0  index  u_id    EMP_NO     MONTH  PERFORMANCE    RATING  Salary  \
# 0        0      0  A100 -0.968136 -0.280405    -1.558455 -0.163386   50000
# 1        1      1  A101  0.095086 -1.543299    -0.802618 -0.126009  100000
#
#       increment      new1
# 0  -4084.649758  0.112391
# 1 -12600.935019 -0.775561

# %%
# Reset to default 0,1...n index
df.reset_index(inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-9fdf093d68a1> in <module>
#       1 # Reset to default 0,1...n index
# ----> 2 df.reset_index(inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5014                 # to ndarray and maybe infer different dtype
#    5015                 level_values = maybe_casted_values(lev, lab)
# -> 5016                 new_obj.insert(0, name, level_values)
#    5017
#    5018         new_obj.index = new_index
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
# ...

# %%
df
# Out:
#    level_0  index  u_id    EMP_NO     MONTH  PERFORMANCE    RATING  Salary  \
# 0        0      0  A100 -0.968136 -0.280405    -1.558455 -0.163386   50000
# 1        1      1  A101  0.095086 -1.543299    -0.802618 -0.126009  100000
#
#       increment      new1
# 0  -4084.649758  0.112391
# 1 -12600.935019 -0.775561

# %%
df.columns
# Out:
# Index(['level_0', 'index', 'u_id', 'EMP_NO', 'MONTH', 'PERFORMANCE', 'RATING',
#        'Salary', 'increment', 'new1'],
#       dtype='object')

# %%
newind = 'CA NY WY OR CO'.split()

# %%
newind
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
df['States'] = newind

# %%
df
# Out:
#   index    EMP_NO     MONTH  PERFORMANCE    RATING States
# 0     A  0.406866 -0.125747    -1.064838 -0.862668     CA
# 1     B -0.869620 -1.072732     1.816617  0.199312     NY
# 2     C  0.788325  1.810708     0.008215 -1.935335     WY
# 3     D  0.263176  0.933798     1.233013  0.224858     OR
# 4     E -1.959341 -1.205183    -0.508318  0.177525     CO

# %%
df.set_index('States' ,inplace = True)

# %%
df
# Out:
#        index    EMP_NO     MONTH  PERFORMANCE    RATING
# States
# CA         A  0.406866 -0.125747    -1.064838 -0.862668
# NY         B -0.869620 -1.072732     1.816617  0.199312
# WY         C  0.788325  1.810708     0.008215 -1.935335
# OR         D  0.263176  0.933798     1.233013  0.224858
# CO         E -1.959341 -1.205183    -0.508318  0.177525

# %%
df.reset_index(inplace = True)

# %%
df.set_index('States',inplace=True)

# %%
df

# %% [markdown]
# # END

# %%
import numpy as np

# %%
a=np.array([[1,3,4],[9,0,1],[1,0,3]])

# %%
a

# %%
a==1

# %%
a[a==1]=22

# %%
a

# %%
df.iloc[1]

# %%
pd.factorize(df.iloc[1])
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  Float64Index([  0.7626206785338688,  0.17641139252316473,  -0.3718354890622697,
#                0.010374502285771034,             200000.0,
#                   2074.900457154207],
#               dtype='float64'))

# %%
d1={"Gender":['M','F','M','M','F'],"Age":[10,23,22,12,33]}

# %%
import pandas as pd
df = pd.read_csv(r"E:\Python\Machine Learning\datasets\bank.csv")

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df.job.unique()
# Out:
# array(['unemployed', 'services', 'management', 'blue-collar',
#        'self-employed', 'technician', 'entrepreneur', 'admin.', 'student',
#        'housemaid', 'retired', 'unknown'], dtype=object)

# %%
df.job.describe()
# Out:
# count           4521
# unique            12
# top       management
# freq             969
# Name: job, dtype: object

# %%
df

# %%
obj  = df.groupby(['job','education'])

# %%
obj.mean()
# Out:
#                                age      balance        day    duration  \
# job           education
# admin.        primary    45.764706   390.588235  12.000000  188.529412
#               secondary  39.722646  1269.679389  16.249364  244.129771
#               tertiary   34.529412  1053.294118  17.372549  168.392157
#               unknown    48.117647  1590.470588  19.235294  260.941176
# blue-collar   primary    42.807588  1072.214092  15.845528  249.306233
#               secondary  38.087786  1068.591603  15.311069  301.198473
#               tertiary   35.833333  2385.500000  13.916667  228.083333
#               unknown    44.000000  1032.878049  14.853659  258.097561
# entrepreneur  primary    44.461538   383.923077  14.230769  250.615385
#               secondary  42.224138  1276.172414  15.362069  320.396552
#               tertiary   40.479452  2585.904110  15.013699  278.342466
#               unknown    45.272727   328.181818  18.727273  231.090909
# ...

# %%
df.groupby('job').mean()
# Out:
#                      age      balance        day    duration  campaign  \
# job
# admin.         39.682008  1226.736402  16.324268  234.669456  2.631799
# blue-collar    40.156448  1085.161734  15.482030  278.161734  2.846723
# entrepreneur   42.011905  1645.125000  15.255952  285.476190  2.589286
# housemaid      47.339286  2083.803571  15.294643  292.633929  2.500000
# management     40.540764  1766.928793  16.254902  260.536636  2.973168
# retired        61.869565  2319.191304  15.556522  285.656522  2.465217
# self-employed  41.453552  1392.409836  16.180328  264.125683  3.278689
# services       38.570743  1103.956835  15.515588  262.486811  2.822542
# student        26.821429  1543.821429  16.392857  248.690476  2.392857
# technician     39.470052  1330.996094  16.183594  252.178385  2.731771
# unemployed     40.906250  1089.421875  16.093750  301.265625  2.679688
# unknown        48.105263  1501.710526  15.842105  216.921053  2.552632
#
#                    pdays  previous
# ...

# %%
df.marital.unique()
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
df.marital.nunique()
# Out:
# 3

# %%
df.marital.value_counts()
# Out:
# married     2797
# single      1196
# divorced     528
# Name: marital, dtype: int64

# %%
df.education.value_counts()
# Out:
# secondary    2306
# tertiary     1350
# primary       678
# unknown       187
# Name: education, dtype: int64

# %%
df.default.value_counts()
# Out:
# no     4445
# yes      76
# Name: default, dtype: int64

# %%
df.contact.value_counts()
# Out:
# cellular     2896
# unknown      1324
# telephone     301
# Name: contact, dtype: int64

# %%
df.head(10)
# Out:
#    age            job  marital  education default  balance housing loan  \
# 0   30     unemployed  married    primary      no     1787      no   no
# 1   33       services  married  secondary      no     4789     yes  yes
# 2   35     management   single   tertiary      no     1350     yes   no
# 3   30     management  married   tertiary      no     1476     yes  yes
# 4   59    blue-collar  married  secondary      no        0     yes   no
# 5   35     management   single   tertiary      no      747      no   no
# 6   36  self-employed  married   tertiary      no      307     yes   no
# 7   39     technician  married  secondary      no      147     yes   no
# 8   41   entrepreneur  married   tertiary      no      221     yes   no
# 9   43       services  married    primary      no      -88     yes  yes
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# ...

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
df['job'].value_counts()
# Out:
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: job, dtype: int64

# %%
df['job'].count()
# Out:
# 4521

# %%
df['job'].unique()
# Out:
# array(['unemployed', 'services', 'management', 'blue-collar',
#        'self-employed', 'technician', 'entrepreneur', 'admin.', 'student',
#        'housemaid', 'retired', 'unknown'], dtype=object)

# %%
df['job'].nunique()
# Out:
# 12

# %% [markdown]
# ## jobwise analysis
#  out of totoal customers 12 are unique job_types and these are

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
df.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
len(df.columns)
# Out:
# 17

# %%
df.job.value_counts()
# Out:
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: job, dtype: int64

# %%
df.describe(include='object')
# Out:
#                job  marital  education default housing  loan   contact month  \
# count         4521     4521       4521    4521    4521  4521      4521  4521
# unique          12        3          4       2       2     2         3    12
# top     management  married  secondary      no     yes    no  cellular   may
# freq           969     2797       2306    4445    2559  3830      2896  1398
#
#        poutcome     y
# count      4521  4521
# unique        4     2
# top     unknown    no
# freq       3705  4000

# %%
df.describe(include='all')
# Out:
#                 age         job  marital  education default       balance  \
# count   4521.000000        4521     4521       4521    4521   4521.000000
# unique          NaN          12        3          4       2           NaN
# top             NaN  management  married  secondary      no           NaN
# freq            NaN         969     2797       2306    4445           NaN
# mean      41.170095         NaN      NaN        NaN     NaN   1422.657819
# std       10.576211         NaN      NaN        NaN     NaN   3009.638142
# min       19.000000         NaN      NaN        NaN     NaN  -3313.000000
# 25%       33.000000         NaN      NaN        NaN     NaN     69.000000
# 50%       39.000000         NaN      NaN        NaN     NaN    444.000000
# 75%       49.000000         NaN      NaN        NaN     NaN   1480.000000
# max       87.000000         NaN      NaN        NaN     NaN  71188.000000
#
#        housing  loan   contact          day month     duration     campaign  \
# ...

# %%
df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
df[['job','marital','education','default','housing','loan','contact','month', 'poutcome','y']].dtypes
# Out:
# job          object
# marital      object
# education    object
# default      object
# housing      object
# loan         object
# contact      object
# month        object
# poutcome     object
# y            object
# dtype: object

# %%
df[['job','marital','education','default','housing','loan','contact','month', 'poutcome','y']].describe()
# Out:
#                job  marital  education default housing  loan   contact month  \
# count         4521     4521       4521    4521    4521  4521      4521  4521
# unique          12        3          4       2       2     2         3    12
# top     management  married  secondary      no     yes    no  cellular   may
# freq           969     2797       2306    4445    2559  3830      2896  1398
#
#        poutcome     y
# count      4521  4521
# unique        4     2
# top     unknown    no
# freq       3705  4000

# %%
df.describe(include=['O'])
# Out:
#                job  marital  education default housing  loan   contact month  \
# count         4521     4521       4521    4521    4521  4521      4521  4521
# unique          12        3          4       2       2     2         3    12
# top     management  married  secondary      no     yes    no  cellular   may
# freq           969     2797       2306    4445    2559  3830      2896  1398
#
#        poutcome     y
# count      4521  4521
# unique        4     2
# top     unknown    no
# freq       3705  4000

# %% [markdown]
# ### AGE wise analysis
# #### 25% of the total customers are below the age of 33.
# #### half of the crowd is having age less than or equal to 39
# ### Balance analysis
# #### half of the total customers are having balance less than or equal to  444

# %%
df['age'].mean()
# Out:
# 41.17009511170095

# %%
df[df.job=='blue-collar'].mean()
# Out:
# age           40.156448
# balance     1085.161734
# day           15.482030
# duration     278.161734
# campaign       2.846723
# pdays         41.590909
# previous       0.493658
# dtype: float64

# %%
df[df.job =='services'].mean()
# Out:
# age           38.570743
# balance     1103.956835
# day           15.515588
# duration     262.486811
# campaign       2.822542
# pdays         36.371703
# previous       0.443645
# dtype: float64

# %%
df_group = df.groupby(['job', 'education','loan']).count()

# %%
df_group['age'].plot()
# Out:
# <AxesSubplot:xlabel='job,education,loan'>

# %%
df.groupby(['job']).mean()
# Out:
#                      age      balance        day    duration  campaign  \
# job
# admin.         39.682008  1226.736402  16.324268  234.669456  2.631799
# blue-collar    40.156448  1085.161734  15.482030  278.161734  2.846723
# entrepreneur   42.011905  1645.125000  15.255952  285.476190  2.589286
# housemaid      47.339286  2083.803571  15.294643  292.633929  2.500000
# management     40.540764  1766.928793  16.254902  260.536636  2.973168
# retired        61.869565  2319.191304  15.556522  285.656522  2.465217
# self-employed  41.453552  1392.409836  16.180328  264.125683  3.278689
# services       38.570743  1103.956835  15.515588  262.486811  2.822542
# student        26.821429  1543.821429  16.392857  248.690476  2.392857
# technician     39.470052  1330.996094  16.183594  252.178385  2.731771
# unemployed     40.906250  1089.421875  16.093750  301.265625  2.679688
# unknown        48.105263  1501.710526  15.842105  216.921053  2.552632
#
#                    pdays  previous
# ...

# %% [markdown]
# #### retired person is having more average balance as compared to any other ocu..

# %% [markdown]
# #### Find out people who are unemployed or blue collar

# %%
df['education'].unique()
# Out:
# array(['primary', 'secondary', 'tertiary', 'unknown'], dtype=object)

# %%
df[((df['job']=='unemployed') | (df['job']=='blue-collar'))& (df['age']>30)][['age','job','balance']]
# Out:
#       age          job  balance
# 4      59  blue-collar        0
# 14     31  blue-collar      360
# 26     55  blue-collar      627
# 37     32  blue-collar     2089
# 42     52  blue-collar     1117
# ...   ...          ...      ...
# 4506   42   unemployed     -166
# 4511   46  blue-collar      668
# 4512   40  blue-collar     1100
# 4513   49  blue-collar      322
# 4514   38  blue-collar     1205
#
# [928 rows x 3 columns]

# %%
df [((df['job']=='unemployed') | (df['job']=='blue-collar'))]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 0      30   unemployed  married    primary      no     1787      no   no
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 14     31  blue-collar  married  secondary      no      360     yes  yes
# 18     25  blue-collar   single    primary      no     -221     yes   no
# 26     55  blue-collar  married    primary      no      627     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4511   46  blue-collar  married  secondary      no      668     yes   no
# 4512   40  blue-collar  married  secondary      no     1100     yes   no
# 4513   49  blue-collar  married  secondary      no      322      no   no
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
df [((df['job']=='unemployed') | (df['job']=='blue-collar')) & (df['education'] =='tertiary')][['job', 'balance','education']]
# Out:
#               job  balance education
# 160   blue-collar       20  tertiary
# 204   blue-collar      455  tertiary
# 239    unemployed     1634  tertiary
# 274   blue-collar        0  tertiary
# 460    unemployed      383  tertiary
# 594    unemployed        0  tertiary
# 608    unemployed     1594  tertiary
# 1044   unemployed      178  tertiary
# 1065   unemployed        0  tertiary
# 1075   unemployed      454  tertiary
# 1161   unemployed      991  tertiary
# 1265   unemployed     7744  tertiary
# 1315  blue-collar     1784  tertiary
# 1407   unemployed     9019  tertiary
# 1648   unemployed      744  tertiary
# 1682   unemployed      415  tertiary
# 1694   unemployed     1798  tertiary
# 1929   unemployed      705  tertiary
# 1962   unemployed      343  tertiary
# 2065   unemployed        0  tertiary
# 2119   unemployed      591  tertiary
# 2249   unemployed      780  tertiary
# 2254   unemployed     -471  tertiary
# 2287   unemployed     1449  tertiary
# ...

# %%
df[df['education']=="unknown"]['job'].value_counts()
# Out:
# blue-collar      41
# management       27
# technician       22
# admin.           17
# student          16
# unknown          15
# retired          14
# services         13
# entrepreneur     11
# housemaid         5
# self-employed     4
# unemployed        2
# Name: job, dtype: int64

# %%
df[(df['job']=='unemployed') | (df['job']=='blue-collar')][['job','housing', 'loan','balance','contact']]
# Out:
#               job housing loan  balance   contact
# 0      unemployed      no   no     1787  cellular
# 4     blue-collar     yes   no        0   unknown
# 14    blue-collar     yes  yes      360  cellular
# 18    blue-collar     yes   no     -221   unknown
# 26    blue-collar     yes   no      627   unknown
# ...           ...     ...  ...      ...       ...
# 4511  blue-collar     yes   no      668   unknown
# 4512  blue-collar     yes   no     1100   unknown
# 4513  blue-collar      no   no      322  cellular
# 4514  blue-collar     yes   no     1205  cellular
# 4519  blue-collar      no   no     1137  cellular
#
# [1074 rows x 5 columns]

# %%
df[df['job']=='blue-collar'][['job','housing', 'loan','balance','contact']]
# Out:
#               job housing loan  balance   contact
# 4     blue-collar     yes   no        0   unknown
# 14    blue-collar     yes  yes      360  cellular
# 18    blue-collar     yes   no     -221   unknown
# 26    blue-collar     yes   no      627   unknown
# 37    blue-collar     yes   no     2089  cellular
# ...           ...     ...  ...      ...       ...
# 4511  blue-collar     yes   no      668   unknown
# 4512  blue-collar     yes   no     1100   unknown
# 4513  blue-collar      no   no      322  cellular
# 4514  blue-collar     yes   no     1205  cellular
# 4519  blue-collar      no   no     1137  cellular
#
# [946 rows x 5 columns]

# %%
import pandas as pd

# %%
pd.read_html()

# %%
extract_date = lambda date_str: {'year': int(date_str[:4]), 'month': int(date_str[5:7]), 'date': int(date_str[8:])} 

date_input = '2025-01-17' 

result = extract_date(date_input) 

print(result)
# Out:
# {'year': 2025, 'month': 1, 'date': 17}

# %%
def deco(fun):
    def wrap(x):
        try:
            print("if ny logic")
            if fun(x)[0]:
                return f(x)[2]
            else:
                raise fun(x)[1]
        except:
            sys.exc_info()[]

# %%
def val_name(name):
    try:
        if re.match(p,name):
            fl=True
            mes = "ok"
        else:
            raise EX("")
    except:
        fl=False
        mes=" not vali"
    return flg, msg, name

# %%
def cal_age()

# %% [markdown]
# Reading multiple files

# %%
import pandas as pd
total_df = []
for i in [i for i in files if i.startswith("experiment") ]:
    var = "df_"+str(i)
    print(var)
    file = 'D:\\ML_code\\datasets\\datasets\\CNC_machine_date\\'+i
    root, extension = os.path.splitext(file)
    print(root, extension)
    
    if extension =='.csv':
        globals()[var] = pd.read_csv(file)
        total_df.append(globals()[var])
        print("process completed")
    
final_df=pd.concat(total_df)
