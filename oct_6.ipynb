# %%
import pandas as pd

# %%
l1=[1.2,20,3,4.5,5.4,6.7,7]

# %%
l1
# Out:
# [1.2, 2, 3, 4.5, 5.4, 6.7, 7]

# %%
S1=pd.Series(l1)

# %%
type(S1)
# Out:
# pandas.core.series.Series

# %%
S1.index=["A","B",'C','D','E','F','G']

# %%
S1
# Out:
# A     1.2
# B    20.0
# C     3.0
# D     4.5
# E     5.4
# F     6.7
# G     7.0
# dtype: float64

# %%
S1[1], S1['G']
# Out:
# (2.0, 7.0)

# %%
S1[S1.argmax()]
# Out:
# 20.0

# %%
S1[S1.argmin()]
# Out:
# 1.2

# %%
S1[S1.argsort()]
# Out:
# A     1.2
# C     3.0
# D     4.5
# E     5.4
# F     6.7
# G     7.0
# B    20.0
# dtype: float64

# %%
S1= S1.astype(str)

# %%
S1
# Out:
# A     1.2
# B    20.0
# C     3.0
# D     4.5
# E     5.4
# F     6.7
# G     7.0
# dtype: object
