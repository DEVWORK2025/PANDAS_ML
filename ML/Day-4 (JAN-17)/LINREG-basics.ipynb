# %%
import random
from math import *
import operator
import pandas as pd
import numpy as np

# import plotting libraries
import matplotlib
import matplotlib.pyplot as plt
#from pandas.plotting import scatter_matrix
# %matplotlib inline 

import seaborn as sns
sns.set(style="white", color_codes=True)
sns.set(font_scale=1.5)


# import the ML algorithm
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from statsmodels.tools.eval_measures import rmse

# %%
height=[[4.0],[4.5],[5.0],[5.2],[5.4],[5.8],[6.1],[6.2],[6.4],[6.8]]

weight=[  42 ,  44 , 49, 55  , 53  , 58   , 60  , 64  ,  66 ,  69]

# %%
list(zip(height,weight))
# Out:
# [([4.0], 42),
#  ([4.5], 44),
#  ([5.0], 49),
#  ([5.2], 55),
#  ([5.4], 53),
#  ([5.8], 58),
#  ([6.1], 60),
#  ([6.2], 64),
#  ([6.4], 66),
#  ([6.8], 69)]

# %%
print("height weight")
for row in zip(height, weight):
    print(row[0][0],"->",row[1])
# Out:
# height weight
# 4.0 -> 42
# 4.5 -> 44
# 5.0 -> 49
# 5.2 -> 55
# 5.4 -> 53
# 5.8 -> 58
# 6.1 -> 60
# 6.2 -> 64
# 6.4 -> 66
# 6.8 -> 69

# %%
# Plotting the height and weight data:

plt.scatter(height, weight, color='black')

plt.xlabel("height")
plt.ylabel("weight")
# Out:
# Text(0, 0.5, 'weight')

# %%
#obj.fit(x,y)
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

reg.fit(height, weight)
# Out:
# LinearRegression()

# %% [markdown]
# #### fit_intercept : boolean, optional, default True
#             whether to calculate the intercept for this model.
#             If set to False, no intercept will be used in calculations (e.g. data is expected to be already centered).
#
# #### normalize : boolean, optional, default False
#             This parameter is ignored when fit_intercept is set to False.
#             If True,
#             the regressors X will be normalized before regression by subtracting the mean and dividing by the l2-norm.
#             If you wish to standardize, sklearn.preprocessing.StandardScaler cana be used before calling fit on an estimator with normalize=False.
#
# #### copy_X : boolean, optional, default True
#             If True, X will be copied; else, it may be overwritten.
#
#
# #### n_jobs : int or None, optional (default=None)
#             The number of jobs to use for the computation. This will only provide speedup for n_targets > 1 and sufficient large problems.

# %%
reg.intercept_
# Out:
# -0.4726651480637756

# %%
reg.coef_
# Out:
# array([10.19362187])

# %%
m = reg.coef_[0]   # slop

b = reg.intercept_

print("slope=",m, "intercept=",b)
# Out:
# slope= 10.193621867881548 intercept= -0.4726651480637756

# %%
[i[0]*2 for i in height if i[0]%2==0]
# Out:
# [8.0]

# %%
l1=[]
for i in height:
    print(i[0], i[0]*2)
    l1.append(i[0]*2)
# Out:
# 4.0 8.0
# 4.5 9.0
# 5.0 10.0
# 5.2 10.4
# 5.4 10.8
# 5.8 11.6
# 6.1 12.2
# 6.2 12.4
# 6.4 12.8
# 6.8 13.6

# %%
plt.scatter(height, weight, color='black')

predicted_values = [reg.coef_ * i + reg.intercept_ for i in height]

plt.plot(height, predicted_values, 'c')

plt.xlabel("height")
plt.ylabel("weight")
# Out:
# Text(0, 0.5, 'weight')

# %%
type(predicted_values)
# Out:
# list

# %%
predicted_values
# Out:
# [array([40.30182232]),
#  array([45.39863326]),
#  array([50.49544419]),
#  array([52.53416856]),
#  array([54.57289294]),
#  array([58.65034169]),
#  array([61.70842825]),
#  array([62.72779043]),
#  array([64.76651481]),
#  array([68.84396355])]

# %%
height=[[4.0],[4.5],[5.0],[5.2],[5.4],[5.8],[6.1],[6.2],[6.4],[6.8]]

weight=[  42 ,  44 , 49, 55  , 53  , 58   , 60  , 64  ,  66 ,  69]

# %%
ans=reg.predict([[6.4]])

# %%
ans
# Out:
# array([64.76651481])

# %%
import numpy as np
np.array([10])
# Out:
# array([10])
