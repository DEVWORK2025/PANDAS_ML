# %%
import pandas as pd

# %%
df = pd.read_csv(r"E:\Python\Machine Learning\datasets\collegedata.csv")

# %%
df
# Out:
#    roll_num    name   class    address          dob
# 0         1    ABCD      11  fkjdfklvj  12-mar-2002
# 1         2    ASFF      11   dlfkdflk  12-mar-2002
# 2         3    ASFW      11      dflkm  12-mar-2002
# 3         4  FGFDFV      11     rtgoke  12-mar-2002
# 4         5    DGFH      11       egkl  12-mar-2002
# 5         6  dfGFGH      11       wefj  12-mar-2002

# %%
df.columns
# Out:
# Index(['roll_num', ' name', ' class', ' address', ' dob'], dtype='object')

# %%
df[' name'].apply(len)
# Out:
# 0    4
# 1    4
# 2    4
# 3    6
# 4    4
# 5    6
# Name:  name, dtype: int64

# %%
df["cnt"]=df[' name'].apply(len)

# %%
df
# Out:
#    roll_num    name   class    address          dob  cnt
# 0         1    ABCD      11  fkjdfklvj  12-mar-2002    4
# 1         2    ASFF      11   dlfkdflk  12-mar-2002    4
# 2         3    ASFW      11      dflkm  12-mar-2002    4
# 3         4  FGFDFV      11     rtgoke  12-mar-2002    6
# 4         5    DGFH      11       egkl  12-mar-2002    4
# 5         6  dfGFGH      11       wefj  12-mar-2002    6
