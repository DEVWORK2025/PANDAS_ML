# %%
# !pip install yahoo_fin

# %%
import yahoo_fin

# %%
from yahoo_fin import stock_info as si

# %%
si.get_data('TSLA')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-9-f7dfeeffc09c> in <module>
# ----> 1 si.get_data('TSLA')
#
# ~\anaconda3\lib\site-packages\yahoo_fin\stock_info.py in get_data(ticker, start_date, end_date, index_as_date, interval)
#      88
#      89     if not resp.ok:
# ---> 90         raise AssertionError(resp.json())
#      91
#      92
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
# ...

# %%
si.get_market_status()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-14-19026de6ac3e> in <module>
# ----> 1 si.get_market_status()
#
# ~\anaconda3\lib\site-packages\yahoo_fin\stock_info.py in get_market_status()
#     938     '''Returns the current state of the market - PRE, POST, OPEN, or CLOSED'''
#     939
# --> 940     quote_data = get_quote_data("^dji")
#     941
#     942     return quote_data["marketState"]
#
# ~\anaconda3\lib\site-packages\yahoo_fin\stock_info.py in get_quote_data(ticker)
#     924
#     925     if not resp.ok:
# --> 926         raise AssertionError("""Invalid response from server.  Check if ticker is
#     927                               valid.""")
#     928
#
# AssertionError: Invalid response from server.  Check if ticker is
#                               valid.

# %%
si.get_dividends('TSLA')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-10-b68f2bbf671d> in <module>
# ----> 1 si.get_dividends('TSLA')
#
# ~\anaconda3\lib\site-packages\yahoo_fin\stock_info.py in get_dividends(ticker, start_date, end_date, index_as_date)
#     661
#     662     if not resp.ok:
# --> 663         raise AssertionError(resp.json())
#     664
#     665
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
# ...

# %%
# !pip install urllib
# Out:
# ERROR: Could not find a version that satisfies the requirement urllib (from versions: none)
# ERROR: No matching distribution found for urllib

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd
df_ttm = pd.read_html('https://finance.yahoo.com/quote/TTM?p=TTM&.tsrc=fin-srch')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-5c1c9689af5d> in <module>
#       1 import pandas as pd
# ----> 2 df_ttm = pd.read_html('https://finance.yahoo.com/quote/TTM?p=TTM&.tsrc=fin-srch')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1083     io = stringify_path(io)
#    1084
# -> 1085     return _parse(
#    1086         flavor=flavor,
#    1087         io=io,
#
# ...
