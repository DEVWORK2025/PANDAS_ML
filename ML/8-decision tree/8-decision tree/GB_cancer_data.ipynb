# %%
import pandas as pd

# %%
df =pd.read_csv(r"E:\Python\Machine Learning\datasets\breastcancer_orig.csv")

# %%
df.head()
# Out:
#       code  Clump_Thickness  Cell_Size  Cell_Shape  Adhesion  \
# 0  1000025                5          1           1         1
# 1  1002945                5          4           4         5
# 2  1015425                3          1           1         1
# 3  1016277                6          8           8         1
# 4  1017023                4          1           1         3
#
#    Epithelial_Cell_Size Bare_Nuclei  Bland_Chromatin  Normal_Nucleoli  \
# 0                     2           1                3                1
# 1                     7          10                3                2
# 2                     2           2                3                1
# 3                     3           4                3                7
# 4                     2           1                3                1
#
#    Mitoses  Class
# 0        1      2
# 1        1      2
# 2        1      2
# 3        1      2
# 4        1      2

# %%
df.shape
# Out:
# (699, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code                  699 non-null    int64
#  1   Clump_Thickness       699 non-null    int64
#  2   Cell_Size             699 non-null    int64
#  3   Cell_Shape            699 non-null    int64
#  4   Adhesion              699 non-null    int64
#  5   Epithelial_Cell_Size  699 non-null    int64
#  6   Bare_Nuclei           699 non-null    object
#  7   Bland_Chromatin       699 non-null    int64
#  8   Normal_Nucleoli       699 non-null    int64
#  9   Mitoses               699 non-null    int64
#  10  Class                 699 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 60.2+ KB

# %%
df.Bare_Nuclei.unique()
# Out:
# array(['1', '10', '2', '4', '3', '9', '7', 0, '5', '8', '6'], dtype=object)

# %%
df[df.Bare_Nuclei=="?"]
# Out:
#         code  Clump_Thickness  Cell_Size  Cell_Shape  Adhesion  \
# 23   1057013                8          4           5         1
# 40   1096800                6          6           6         9
# 139  1183246                1          1           1         1
# 145  1184840                1          1           3         1
# 158  1193683                1          1           2         1
# 164  1197510                5          1           1         1
# 235  1241232                3          1           4         1
# 249   169356                3          1           1         1
# 275   432809                3          1           3         1
# 292   563649                8          8           8         1
# 294   606140                1          1           1         1
# 297    61634                5          4           3         1
# 315   704168                4          6           5         6
# 321   733639                3          1           1         1
# ...

# %%
df
# Out:
#         code  Clump_Thickness  Cell_Size  Cell_Shape  Adhesion  \
# 0    1000025                5          1           1         1
# 1    1002945                5          4           4         5
# 2    1015425                3          1           1         1
# 3    1016277                6          8           8         1
# 4    1017023                4          1           1         3
# ..       ...              ...        ...         ...       ...
# 694   776715                3          1           1         1
# 695   841769                2          1           1         1
# 696   888820                5         10          10         3
# 697   897471                4          8           6         4
# 698   897471                4          8           8         5
#
#      Epithelial_Cell_Size Bare_Nuclei  Bland_Chromatin  Normal_Nucleoli  \
# 0                       2           1                3                1
# ...

# %%
df.Bare_Nuclei = df.Bare_Nuclei.replace('?',0)

# %%
df.Bare_Nuclei = df.Bare_Nuclei.astype('int')
# Out:
# 0       1
# 1      10
# 2       2
# 3       4
# 4       1
#        ..
# 694     2
# 695     1
# 696     3
# 697     4
# 698     5
# Name: Bare_Nuclei, Length: 699, dtype: int32

# %%
train =df[df.Bare_Nuclei==0]

# %%
test =df[df.Bare_Nuclei==0]

# %%
test
# Out:
#         code  Clump_Thickness  Cell_Size  Cell_Shape  Adhesion  \
# 23   1057013                8          4           5         1
# 40   1096800                6          6           6         9
# 139  1183246                1          1           1         1
# 145  1184840                1          1           3         1
# 158  1193683                1          1           2         1
# 164  1197510                5          1           1         1
# 235  1241232                3          1           4         1
# 249   169356                3          1           1         1
# 275   432809                3          1           3         1
# 292   563649                8          8           8         1
# 294   606140                1          1           1         1
# 297    61634                5          4           3         1
# 315   704168                4          6           5         6
# 321   733639                3          1           1         1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code                  699 non-null    int64
#  1   Clump_Thickness       699 non-null    int64
#  2   Cell_Size             699 non-null    int64
#  3   Cell_Shape            699 non-null    int64
#  4   Adhesion              699 non-null    int64
#  5   Epithelial_Cell_Size  699 non-null    int64
#  6   Bare_Nuclei           699 non-null    object
#  7   Bland_Chromatin       699 non-null    int64
#  8   Normal_Nucleoli       699 non-null    int64
#  9   Mitoses               699 non-null    int64
#  10  Class                 699 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 60.2+ KB

# %%
X=df[['Clump_Thickness','Cell_Size','Cell_Shape','Adhesion','Epithelial_Cell_Size','Bare_Nuclei','Bland_Chromatin','Normal_Nucleoli','Mitoses']]

# %%
y=df["Class"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train, y_test=train_test_split(X,y)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (524, 9)
# (524,)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn.ensemble import

# %%
gb=GradientBoostingClassifier()

# %%
gb.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred = gb.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[119,   6],
#        [  2,  48]], dtype=int64)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.98      0.95      0.97       125
#            4       0.89      0.96      0.92        50
#
#     accuracy                           0.95       175
#    macro avg       0.94      0.96      0.95       175
# weighted avg       0.96      0.95      0.95       175

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9542857142857143
