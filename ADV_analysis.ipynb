# %%
import pandas as pd
adv = pd.read_csv(r'D:\ML_code\datasets\datasets\Advertising.csv')
adv
# Out:
#       Month     TV  radio  newspaper  sales
# 0    Jan-00  230.1   37.8       69.2   22.1
# 1    Feb-00   44.5   39.3       45.1   10.4
# 2    Mar-00   17.2   45.9       69.3    9.3
# 3    Apr-00  151.5   41.3       58.5   18.5
# 4    May-00  180.8   10.8       58.4   12.9
# ..      ...    ...    ...        ...    ...
# 195  16-Apr   38.2    3.7       13.8    7.6
# 196  16-May   94.2    4.9        8.1    9.7
# 197  16-Jun  177.0    9.3        6.4   12.8
# 198  16-Jul  283.6   42.0       66.2   25.5
# 199  16-Aug  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
adv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Month      200 non-null    object
#  1   TV         200 non-null    float64
#  2   radio      200 non-null    float64
#  3   newspaper  200 non-null    float64
#  4   sales      200 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 7.9+ KB

# %%
adv.dtypes
# Out:
# Month         object
# TV           float64
# radio        float64
# newspaper    float64
# sales        float64
# dtype: object

# %%
adv.isna().sum()
# Out:
# Month        0
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
adv.loc[ 3:10, ['TV','newspaper']]
# Out:
#        TV  newspaper
# 3   151.5       58.5
# 4   180.8       58.4
# 5     8.7       75.0
# 6    57.5       23.5
# 7   120.2       11.6
# 8     8.6        1.0
# 9   199.8       21.2
# 10   66.1       24.2

# %%
adv[adv['TV']>200]
# Out:
#       Month     TV  radio  newspaper  sales
# 0    Jan-00  230.1   37.8       69.2   22.1
# 11   Dec-00  214.7   24.0        4.0   17.4
# 14   01-Mar  204.1   32.9       46.0   19.0
# 17   01-Jun  281.4   39.6       55.8   24.4
# 20   01-Sep  218.4   27.7       53.4   18.0
# ..      ...    ...    ...        ...    ...
# 184  15-May  253.8   21.3       30.0   17.6
# 185  15-Jun  205.0   45.1       19.6   22.6
# 188  15-Sep  286.0   13.9        3.7   15.9
# 198  16-Jul  283.6   42.0       66.2   25.5
# 199  16-Aug  232.1    8.6        8.7   13.4
#
# [67 rows x 5 columns]

# %%
adv[adv['TV']>200]['TV']
# Out:
# 0      230.1
# 11     214.7
# 14     204.1
# 17     281.4
# 20     218.4
#        ...
# 184    253.8
# 185    205.0
# 188    286.0
# 198    283.6
# 199    232.1
# Name: TV, Length: 67, dtype: float64

# %%
adv[(adv['TV']>200) & (adv['radio'] >40)]
# Out:
#       Month     TV  radio  newspaper  sales
# 36   03-Jan  266.9   43.8        5.0   25.4
# 47   03-Dec  239.9   41.5       18.5   23.2
# 52   04-May  216.4   41.7       39.6   22.6
# 58   04-Nov  210.8   49.6       37.7   23.8
# 61   05-Feb  261.3   42.7       54.7   24.2
# 69   05-Oct  216.8   43.9       27.2   22.3
# 84   07-Jan  213.5   43.0       33.8   21.7
# 98   08-Mar  289.7   42.3       51.2   25.4
# 128  10-Sep  220.3   49.0        3.2   24.7
# 147  12-Apr  243.2   49.0       44.3   25.4
# 175  14-Aug  276.9   48.9       41.8   27.0
# 183  15-Apr  287.6   43.0       71.8   26.2
# 185  15-Jun  205.0   45.1       19.6   22.6
# 198  16-Jul  283.6   42.0       66.2   25.5

# %%
adv['TV'].max()
# Out:
# np.float64(296.4)

# %%
dec_adv =adv.describe()

# %%
type(dec_adv)
dec_adv
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
adv['TV'].std()
# Out:
# np.float64(85.85423631490808)

# %%
adv.describe().index
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %%
adv.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
"1st std" ,147.04+85.85
# Out:
# ('1st std', 232.89)

# %%
"-1 std", 147.04-85.85
# Out:
# ('-1 std', 61.19)

# %%
147.04 + (2*85.85)
# Out:
# 318.74

# %%
147.04 - (2*85)
# Out:
# -22.960000000000008

# %%
import matplotlib.pyplot
adv.TV.plot(kind= 'density')
# Out:
# <Axes: ylabel='Density'>

# %%
import numpy as np

var = np.random.randn(30)

# %%
var = pd.Series(var)

# %%
var.plot(kind= 'density')
# Out:
# <Axes: ylabel='Density'>

# %%
cen = var.mean()

# %%
dev = var.std()

# %%
cen + dev
# Out:
# np.float64(1.2214671439998235)

# %%
cen-dev
# Out:
# np.float64(-0.8285499490775365)

# %%
var [ var <cen - 3*dev]
# Out:
# Series([], dtype: float64)

# %%
cen - 3*dev
# Out:
# np.float64(-2.878567042154897)
